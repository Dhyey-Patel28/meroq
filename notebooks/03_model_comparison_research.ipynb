# %% [markdown]
# # Model comparison research
#
# Compare models outside the UI using the same production modules.

# %%
from src.data_loader import fetch_price_data
from src.features import build_model_frame
from src.model import compare_models_simple_split

raw = fetch_price_data("AAPL", period="5y", interval="1d")
frame = build_model_frame(raw)
comparison, results = compare_models_simple_split(frame, model_names=["momentum_baseline", "logistic_regression", "random_forest", "xgboost"])
comparison
