# %% [markdown]
# # Model comparison research

# %% [markdown]
# Compare models outside the Streamlit app for deeper experiments.

# %%
from src.data_loader import load_prices_from_sqlite
from src.features import build_model_frame
from src.model import compare_models_simple_split

# raw = load_prices_from_sqlite('AAPL', interval='1d')
# frame = build_model_frame(raw)
# compare_models_simple_split(frame).head()
