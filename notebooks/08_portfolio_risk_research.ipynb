# %% [markdown]
# # Portfolio Risk Research
#
# This notebook sketches how to analyze a Meroq watchlist as a weighted portfolio.

# %%
from src.portfolio import parse_portfolio_weights, build_portfolio_view
from src.watchlist import scan_watchlist

tickers = ["AAPL", "MSFT", "NVDA", "SPY"]
weights = parse_portfolio_weights(tickers, "AAPL:30, MSFT:25, NVDA:25, SPY:20")
weights

# %%
# scan_df = scan_watchlist(tickers, period="5y", interval="1d", include_sentiment=True, include_risk=True)
# portfolio_df, summary = build_portfolio_view(scan_df, weights)
# summary
