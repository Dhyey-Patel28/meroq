# %% [markdown]
# # Risk simulation research

# %% [markdown]
# Explore Monte Carlo assumptions and simulated outcome distributions.

# %%
from src.data_loader import load_prices_from_sqlite
from src.risk_simulation import simulate_price_paths

# raw = load_prices_from_sqlite('AAPL', interval='1d')
# result = simulate_price_paths(raw, horizon_days=30, n_paths=1000)
# result['summary']
