# %% [markdown]
# # News sentiment research

# %% [markdown]
# Explore headline collection, source coverage, and sentiment behavior.

# %%
from src.news_sentiment import fetch_news_for_ticker, analyze_news_sentiment, summarize_sentiment

news, meta = fetch_news_for_ticker('AAPL', source='all_configured', max_items=20)
meta

# %%
scored = analyze_news_sentiment(news, engine='lightweight')
summarize_sentiment(scored), scored.head()
