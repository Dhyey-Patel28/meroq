# %% [markdown]
# # Price feature audit

# %% [markdown]
# Load saved local price data and inspect engineered feature quality.

# %%
import pandas as pd
from pathlib import Path
from src.storage import inspect_market_database
inspect_market_database()

# %%
from src.data_loader import load_prices_from_sqlite
from src.features import build_model_frame

# Example after data has been refreshed locally:
# raw = load_prices_from_sqlite('AAPL', interval='1d')
# model_frame = build_model_frame(raw)
# model_frame.tail()
